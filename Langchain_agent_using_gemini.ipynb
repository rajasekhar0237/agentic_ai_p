# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages (26.0.1)

# %%
import os 
import warnings 
import pandas as pd 
warnings.filterwarnings("ignore")

# %%
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from langchain_experimental.agents import create_pandas_dataframe_agent
#       2 from langchain_google_genai import ChatGoogleGenerativeAI
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_experimental\agents\__init__.py:11
#       1 """**Agent** is a class that uses an LLM to choose
#       2 a sequence of actions to take.
#       3
#    (...)      8 Agents select and use **Tools** and **Toolkits** for actions.
#       9 """
# ---> 11 from langchain_experimental.agents.agent_toolkits import (
#      12     create_csv_agent,
#      13     create_pandas_dataframe_agent,
#      14     create_spark_dataframe_agent,
#      15     create_xorbits_agent,
#      16 )
#      18 __all__ = [
#      19     "create_csv_agent",
#      20     "create_pandas_dataframe_agent",
#      21     "create_spark_dataframe_agent",
#      22     "create_xorbits_agent",
#      23 ]
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_experimental\agents\agent_toolkits\__init__.py:1
# ----> 1 from langchain_experimental.agents.agent_toolkits.csv.base import create_csv_agent
#       2 from langchain_experimental.agents.agent_toolkits.pandas.base import (
#       3     create_pandas_dataframe_agent,
#       4 )
#       5 from langchain_experimental.agents.agent_toolkits.python.base import create_python_agent
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_experimental\agents\agent_toolkits\csv\base.py:6
#       3 from io import IOBase
#       4 from typing import TYPE_CHECKING, Any, List, Optional, Union
# ----> 6 from langchain_experimental.agents.agent_toolkits.pandas.base import (
#       7     create_pandas_dataframe_agent,
#       8 )
#      10 if TYPE_CHECKING:
#      11     from langchain_classic.agents.agent import AgentExecutor
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:6
#       3 import warnings
#       4 from typing import Any, Dict, List, Literal, Optional, Sequence, Union, cast
# ----> 6 from langchain_classic.agents import (
#       7     AgentType,
#       8     create_openai_tools_agent,
#       9     create_react_agent,
#      10     create_tool_calling_agent,
#      11 )
#      12 from langchain_classic.agents.agent import (
#      13     AgentExecutor,
#      14     BaseMultiActionAgent,
#    (...)     17     RunnableMultiActionAgent,
#      18 )
#      19 from langchain_classic.agents.mrkl.prompt import FORMAT_INSTRUCTIONS
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\agents\__init__.py:34
#      32 from langchain_classic.agents.conversational.base import ConversationalAgent
#      33 from langchain_classic.agents.conversational_chat.base import ConversationalChatAgent
# ---> 34 from langchain_classic.agents.initialize import initialize_agent
#      35 from langchain_classic.agents.json_chat.base import create_json_chat_agent
#      36 from langchain_classic.agents.loading import load_agent
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\agents\initialize.py:15
#      13 from langchain_classic.agents.agent import AgentExecutor
#      14 from langchain_classic.agents.agent_types import AgentType
# ---> 15 from langchain_classic.agents.loading import load_agent
#      16 from langchain_classic.agents.types import AGENT_TO_CLASS
#      19 @deprecated(
#      20     "0.1.0",
#      21     message=AGENT_DEPRECATION_WARNING,
#    (...)     33     **kwargs: Any,
#      34 ) -> AgentExecutor:
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\agents\loading.py:15
#      13 from langchain_classic.agents.agent import BaseMultiActionAgent, BaseSingleActionAgent
#      14 from langchain_classic.agents.types import AGENT_TO_CLASS
# ---> 15 from langchain_classic.chains.loading import load_chain, load_chain_from_config
#      17 logger = logging.getLogger(__name__)
#      19 URL_BASE = "https://raw.githubusercontent.com/hwchase17/langchain-hub/master/agents/"
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\chains\loading.py:17
#      10 from langchain_core._api import deprecated
#      11 from langchain_core.prompts.loading import (
#      12     _load_output_parser,
#      13     load_prompt,
#      14     load_prompt_from_config,
#      15 )
# ---> 17 from langchain_classic.chains import ReduceDocumentsChain
#      18 from langchain_classic.chains.api.base import APIChain
#      19 from langchain_classic.chains.base import Chain
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\chains\__init__.py:93, in __getattr__(name)
#      92 def __getattr__(name: str) -> Any:
# ---> 93     return importer(name)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\_api\module_import.py:73, in create_importer.<locals>.import_by_name(name)
#      70     raise AssertionError(msg)
#      72 try:
# ---> 73     module = importlib.import_module(new_module)
#      74 except ModuleNotFoundError as e:
#      75     if new_module.startswith("langchain_community"):
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\chains\combine_documents\__init__.py:3
#       1 """Different ways to combine documents."""
# ----> 3 from langchain_classic.chains.combine_documents.reduce import (
#       4     acollapse_docs,
#       5     collapse_docs,
#       6     split_list_of_docs,
#       7 )
#       8 from langchain_classic.chains.combine_documents.stuff import (
#       9     create_stuff_documents_chain,
#      10 )
#      12 __all__ = [
#      13     "acollapse_docs",
#      14     "collapse_docs",
#      15     "create_stuff_documents_chain",
#      16     "split_list_of_docs",
#      17 ]
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\chains\combine_documents\reduce.py:13
#      10 from langchain_core.documents import Document
#      11 from pydantic import ConfigDict
# ---> 13 from langchain_classic.chains.combine_documents.base import BaseCombineDocumentsChain
#      16 class CombineDocsProtocol(Protocol):
#      17     """Interface for the combine_docs method."""
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_classic\chains\combine_documents\base.py:15
#      13 from langchain_core.runnables.config import RunnableConfig
#      14 from langchain_core.utils.pydantic import create_model
# ---> 15 from langchain_text_splitters import RecursiveCharacterTextSplitter, TextSplitter
#      16 from pydantic import BaseModel, Field
#      17 from typing_extensions import override
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_text_splitters\__init__.py:39
#      37 from langchain_text_splitters.nltk import NLTKTextSplitter
#      38 from langchain_text_splitters.python import PythonCodeTextSplitter
# ---> 39 from langchain_text_splitters.sentence_transformers import (
#      40     SentenceTransformersTokenTextSplitter,
#      41 )
#      42 from langchain_text_splitters.spacy import SpacyTextSplitter
#      44 __all__ = [
#      45     "CharacterTextSplitter",
#      46     "ElementType",
#    (...)     68     "split_text_on_tokens",
#      69 ]
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_text_splitters\sentence_transformers.py:11
#       7 from langchain_text_splitters.base import TextSplitter, Tokenizer, split_text_on_tokens
#       9 try:
#      10     # Type ignores needed as long as sentence-transformers doesn't support Python 3.14.
# ---> 11     from sentence_transformers import (  # type: ignore[import-not-found, unused-ignore]
#      12         SentenceTransformer,
#      13     )
#      15     _HAS_SENTENCE_TRANSFORMERS = True
#      16 except ImportError:
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:35
#      33 from sentence_transformers import __version__
#      34 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 35 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      36 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      37 from sentence_transformers.cross_encoder.util import (
#      38     cross_encoder_init_args_decorator,
#      39     cross_encoder_predict_rank_args_decorator,
#      40 )
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:21
#      19 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
#      20 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 21 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      22 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      23 from sentence_transformers.readers import InputExample
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\SentenceTransformer.py:36
#      33 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
#      34 from typing_extensions import deprecated
# ---> 36 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      37 from sentence_transformers.models import Router
#      38 from sentence_transformers.models.Module import Module
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\model_card.py:26
#      24 from tqdm.autonotebook import tqdm
#      25 from transformers import TrainerCallback
# ---> 26 from transformers.integrations import CodeCarbonCallback
#      27 from transformers.modelcard import make_markdown_table
#      28 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\integrations\integration_utils.py:60
#      57 logger = logging.get_logger(__name__)
#      59 if is_tf_available():
# ---> 60     from .. import TFPreTrainedModel
#      62 if is_torch_available():
#      63     import torch
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2315 elif name in self._class_to_module:
#    2316     try:
# -> 2317         module = self._get_module(self._class_to_module[name])
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2343 def _get_module(self, module_name: str):
#    2344     try:
# -> 2345         return importlib.import_module("." + module_name, self.__name__)
#    2346     except Exception as e:
#    2347         raise e
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\modeling_tf_utils.py:38
#      35 from packaging.version import parse
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#      40 from .dynamic_module_utils import custom_object_save
#
# File c:\Users\kraja\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\activations_tf.py:27
#      24     import keras
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#      35     """
#      36     Gaussian Error Linear Unit. Original Implementation of the gelu activation function in Google Bert repo when
#      37     initially created. For information: OpenAI GPT's gelu is slightly different (and gives slightly different results):
#      38     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3)))) Also see
#      39     https://huggingface.co/papers/1606.08415
#      40     """
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
